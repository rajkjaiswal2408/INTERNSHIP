# %% [markdown]
# # WEB SCRAPPPING USING SELENIUM

# %%
#install selenium
# !pip install selenium

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location.

# %% [markdown]
# Youhave to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data. This task will be done in following steps:
#
# First get the webpage https://www.naukri.com/
# Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field. 3. Then click the search button. 4. Then scrape the data for the first 10 jobs results you get. 5. Finally create a dataframe of the scraped data

# %%
# Let's import all required libraries

import selenium                                  #library that is used to work with selenium

from selenium import webdriver                   #importing webdriver module from selenium to open automated chrome window

import pandas as pd                              #to create DataFrame

from selenium.webdriver.common.by import By      #importing inbuilt class By 

import warnings                                  #to ignore any sort of warning

warnings.filterwarnings("ignore")

import time                                      #use to stop search engine for few seconds



driver = webdriver.Chrome()

driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys("Bangalore")

search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
for i in driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')[0:10]:
    job_title.append(i.text)
    
# Scrapping job location from the webpage
job_location=[]
for i in driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')[0:10]:
    job_location.append(i.text)

# Scrapping Company Name from the webpage
company_name=[]
for i in driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')[0:10]:
    company_name.append(i.text)

# Scrapping Experience from the webpage
experience_required=[]
for i in driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')[0:10]:
    experience_required.append(i.text)
    
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Job_Title':job_title,'Job_Location':job_location,'Company_Name':company_name,'Experience_required':experience_required})
df.index +=1
df
# Out:
#                                             Job_Title  \
# 1                             Data Science Specialist
# 2                                      Data Scientist
# 3                    Analystics & Modeling Specialist
# 4                      Data Scientist -ML, DL, Python
# 5                                      DATA SCIENTIST
# 6                                      Data Scientist
# 7   ACN - Applied Intelligence - Finance - Data Sc...
# 8                               Senior Data Scientist
# 9                       Sr . Data Scientist / Manager
# 10                                     Data Scientist
#
#                                          Job_Location       Company_Name  \
# 1   Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...          Accenture
# 2             Bangalore/Bengaluru, Mumbai (All Areas)                PwC
# 3   Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...          Accenture
# 4                                 Bangalore/Bengaluru              Capco
# ...

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# you have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys("Bangalore")

search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
for i in driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')[0:10]:
    job_title.append(i.text)
    
# Scrapping job location from the webpage
job_location=[]
for j in driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')[0:10]:
    job_location.append(j.text)

# Scrapping Company Name from the webpage
company_name=[]
for k in driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')[0:10]:
    company_name.append(k.text)
    
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'Job_Title':job_title,'Job_Location':job_location,'Company_Name':company_name})
df.index +=1
df
# Out:
#                                             Job_Title  \
# 1                             Data Science Specialist
# 2                                      Data Scientist
# 3                    Analystics & Modeling Specialist
# 4                      Data Scientist -ML, DL, Python
# 5                                      DATA SCIENTIST
# 6                                      Data Scientist
# 7   ACN - Applied Intelligence - Finance - Data Sc...
# 8                               Senior Data Scientist
# 9                       Sr . Data Scientist / Manager
# 10                                     Data Scientist
#
#                                          Job_Location       Company_Name
# 1   Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...          Accenture
# 2             Bangalore/Bengaluru, Mumbai (All Areas)                PwC
# 3   Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...          Accenture
# 4                                 Bangalore/Bengaluru              Capco
# ...

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys("DELHI/NCR")

search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
for i in driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')[0:10]:
    job_title.append(i.text)
    
# Scrapping job location from the webpage
job_location=[]
for i in driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')[0:10]:
    job_location.append(i.text)

# Scrapping Company Name from the webpage
company_name=[]
for i in driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')[0:10]:
    company_name.append(i.text)

# Scrapping Experience from the webpage
experience_required=[]
for i in driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')[0:10]:
    experience_required.append(i.text)
    
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Job_Title':job_title,'Job_Location':job_location,'Company_Name':company_name,'Experience_required':experience_required})
df.index +=1
df
# Out:
#                                             Job_Title  \
# 1                               Junior Data Scientist
# 2                                      Data Scientist
# 3   Data Scientist/ Senior Data Scientist/ Manager...
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                               Python and ML Trainer
# 7                                              Intern
# 8                           Hiring For Data Scientist
# 9                               Junior Data Scientist
# 10                Associate Data Scientist - ML & NLP
#
#                                          Job_Location  \
# 1   Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 2               Gurgaon/Gurugram, Bangalore/Bengaluru
# 3   Noida, Kolkata, Mumbai, Chandigarh, Hyderabad/...
# 4   Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 5                                               Noida
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
url="https://www.flipkart.com/"
driver.get(url)

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('Sunglasses')
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
product_tag=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
len(product_tag)
# Out:
# 40

# %%
product=[]
for i in product_tag:
    product.append(i.text)

price_tag=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')

price=[]
for i in price_tag:
    price.append(i.text)
    
discount_tag=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')

discount=[]
for i in discount_tag:
    discount.append(i.text)
    
company_tag=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    
company=[]
for i in company_tag:
    company.append(i.text)
    
print(len(product),len(price),len(discount),len(company))
# Out:
# 40 40 40 40

# %%
df1=pd.DataFrame({'Product':product,'Price':price,'Discount':discount,'Company':company})
df1.index +=1
df1
# Out:
#            Product   Price Discount         Company
# 1   ROZZETTA CRAFT    ₹392  80% off  ROZZETTA CRAFT
# 2    VINCENT CHASE    ₹949  52% off   VINCENT CHASE
# 3        Elligator    ₹168  71% off       Elligator
# 4             SRPM    ₹194  85% off            SRPM
# 5          Styloze    ₹183  74% off         Styloze
# 6             SRPM    ₹194  85% off            SRPM
# 7          eyedens    ₹599  88% off         eyedens
# 8    VINCENT CHASE    ₹883  55% off   VINCENT CHASE
# 9         Fastrack    ₹539  40% off        Fastrack
# 10      iCopertina    ₹199  80% off      iCopertina
# 11    Singco India    ₹359  82% off    Singco India
# 12       ROYAL SON    ₹471  68% off       ROYAL SON
# 13         ROADWAY    ₹372  81% off         ROADWAY
# 14            RMKK    ₹249  75% off            RMKK
# 15       Elligator    ₹199  80% off       Elligator
# 16          PIRASO    ₹309  80% off          PIRASO
# 17   VINCENT CHASE    ₹850  57% off   VINCENT CHASE
# ...

# %%
next_page=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div/div[2]/div[12]/div/div/nav/a[11]')
next_page.click()

# %%
product_tag=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')

product=[]
for i in product_tag:
    product.append(i.text)
product=product[:30]

price_tag=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')

price=[]
for i in price_tag:
    price.append(i.text)
price=price[:30]

discount_tag=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')

discount=[]
for i in discount_tag:
    discount.append(i.text)
discount=discount[:30]

company_tag=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')

company=[]
for i in company_tag:
    company.append(i.text)
company=company[:30]

# %%
df2=pd.DataFrame({'Product':product,'Price':price,'Discount':discount,'Company':company})
df2.index +=1
df2
# Out:
#            Product   Price Discount  \
# 1   ROZZETTA CRAFT    ₹392  80% off
# 2    VINCENT CHASE    ₹883  55% off
# 3             BKGE    ₹199  80% off
# 4           Sukart    ₹281  71% off
# 5           PIRASO    ₹322  87% off
# 6        Rich Club    ₹335  66% off
# 7     Singco India    ₹359  82% off
# 8        ROYAL SON    ₹471  68% off
# 9         Fastrack    ₹749  46% off
# 10          PIRASO    ₹245  84% off
# 11   VINCENT CHASE    ₹949  52% off
# 12   VINCENT CHASE    ₹850  57% off
# 13  ROZZETTA CRAFT    ₹480  75% off
# 14    Singco India    ₹599  70% off
# 15    Singco India    ₹396  80% off
# 16    Silver Kartz    ₹268  82% off
# 17  ROZZETTA CRAFT    ₹360  81% off
# 18          Resist  ₹1,406  64% off
# 19          RBGIIT    ₹239  60% off
# 20       Rich Club    ₹395  80% off
# 21       ROYAL SON    ₹359  76% off
# 22            hipe    ₹259  86% off
# 23          Sukart    ₹282  71% off
# 24       Elligator    ₹152  88% off
# 25         ROADWAY    ₹256  80% off
# ...

# %%
next_page=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div/div[2]/div[12]/div/div/nav/a[12]')
next_page.click()

# %%
product_tag=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')

product=[]
for i in product_tag:
    product.append(i.text)
product=product[:30]

price_tag=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')

price=[]
for i in price_tag:
    price.append(i.text)
price=price[:30]

discount_tag=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')

discount=[]
for i in discount_tag:
    discount.append(i.text)
discount=discount[:30]

company_tag=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')

company=[]
for i in company_tag:
    company.append(i.text)
company=company[:30]

# %%
df3=pd.DataFrame({'Product':product,'Price':price,'Discount':discount,'Company':company})
df3.index +=1
df3
# Out:
#            Product   Price Discount  \
# 1   ROZZETTA CRAFT    ₹392  80% off
# 2    VINCENT CHASE    ₹949  52% off
# 3        METRONAUT    ₹249  80% off
# 4        Elligator    ₹194  85% off
# 5         Fastrack    ₹529  41% off
# 6   ROZZETTA CRAFT    ₹399  85% off
# 7    VINCENT CHASE    ₹883  55% off
# 8     Singco India    ₹359  82% off
# 9           PIRASO    ₹397  84% off
# 10      LIZA ANGEL    ₹249  80% off
# 11       ROYAL SON    ₹471  68% off
# 12   VINCENT CHASE    ₹850  57% off
# 13       ROYAL SON    ₹359  76% off
# 14      LIZA ANGEL    ₹249  64% off
# 15            SRPM    ₹229  77% off
# 16       Elligator    ₹174  65% off
# 17  ROZZETTA CRAFT    ₹360  81% off
# 18       ROYAL SON    ₹359  76% off
# 19          PIRASO    ₹249  84% off
# 20       New Specs    ₹199  80% off
# 21          Resist  ₹1,406  64% off
# 22            hipe    ₹259  86% off
# 23       ROYAL SON    ₹359  76% off
# 24      LIZA ANGEL    ₹199  60% off
# 25          GANSTA    ₹224  82% off
# ...

# %%
concatenated_data = pd.concat([df1, df2, df3], axis=0)
concatenated_data
# Out:
#            Product   Price Discount  \
# 1   ROZZETTA CRAFT    ₹392  80% off
# 2    VINCENT CHASE    ₹949  52% off
# 3        Elligator    ₹168  71% off
# 4             SRPM    ₹194  85% off
# 5          Styloze    ₹183  74% off
# ..             ...     ...      ...
# 26       ROYAL SON    ₹639  68% off
# 27     john jacobs  ₹2,499  50% off
# 28   VINCENT CHASE    ₹949  52% off
# 29          PIRASO    ₹239  85% off
# 30          PIRASO    ₹392  84% off
#
#                                            Company
# 1                                   ROZZETTA CRAFT
# 2                                    VINCENT CHASE
# 3                                        Elligator
# 4                                             SRPM
# 5                                          Styloze
# ..                                             ...
# 26           UV Protection Aviator Sunglasses (59)
# 27  Polarized, UV Protection Round Sunglasses (50)
# 28          UV Protection Wayfarer Sunglasses (56)
# ...

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone

# %%
url="https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market"
driver.get(url)

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')


review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)
    
ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)

# %%
df1=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df1.index +=1
df1
# Out:
#          Review_Summary                                        Full_Review  \
# 1              Terrific                                     Very very good
# 2        Classy product  Camera is awesome\nBest battery backup\nA perf...
# 3             Wonderful                             This is amazing at all
# 4             Brilliant                                   Excellent Phone.
# 5             Must buy!                                It’s really awesome
# 6             Just wow!                                  Perfect Product!!
# 7      Perfect product!                                         V Good all
# 8   Best in the market!                                        Good Camera
# 9     Terrific purchase                                  Value for money 😍
# 10            Must buy!  Go for iPhone 11 , if confused between iPhone ...
#
#    Ratings
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5

# %%
next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
next_btn.click()

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')

review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)

ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)

# %%
df2=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df2.index +=1
df2
# Out:
#          Review_Summary                                        Full_Review  \
# 1               Awesome  I dreamt about this day from a long time.... G...
# 2             Wonderful  If you get it you would definitely not regret ...
# 3        Simply awesome                          Buy it if you afford it 😜
# 4       Worth the money                              Camera is just wow 👌👌
# 5               Awesome  Always love the apple products, upgraded from ...
# 6             Excellent                                                NYC
# 7   Best in the market!  Damn this phone is a blast . Upgraded from and...
# 8    Highly recommended  Awesome Battery Life...Camera clarity is too g...
# 9   Best in the market!         Superbb performance n camera is awesome 😍😍
# 10            Just wow!  Nice product\nThe camera is extremely good whi...
#
#    Ratings
# 1        5
# 2        5
# 3        5
# 4        4
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5

# %%
next_btn=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]')
next_btn.click()

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')

review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)

ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)

# %%
df3=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df3.index +=1
df3
# Out:
#          Review_Summary                                        Full_Review  \
# 1        Classy product  We are on apple ecosystem for almost eight yea...
# 2   Best in the market!  Just awesome everything is perfect.\nCamera ou...
# 3    Highly recommended                        Loving it!!!Great product👌🏻
# 4             Just wow!                                    Excellent Phone
# 5                Super!  Did an upgrade from 6s plus to iphone 11.\nAo ...
# 6             Just wow!  Best in class. Battery backup is good especial...
# 7             Excellent  Using this phone from last 4days, great camera...
# 8          Does the job                                 Very good ☺️ phone
# 9     Worth every penny  It is better to buy iPhone 11 over iPhone 12 i...
# 10            Must buy!  My dream is complete just mind-blowing phone c...
#
#    Ratings
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        3
# 9        5
# 10       5

# %%
next_btn=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]')
next_btn.click()

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')

review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)

ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)

# %%
df4=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df4.index +=1
df4
# Out:
#          Review_Summary                                        Full_Review  \
# 1    Highly recommended                            Awesome Best iPhone 😍👍🏼
# 2       Value-for-money  I'm Really happy with the product\nDelivery wa...
# 3     Worth every penny  Previously I was using one plus 3t it was a gr...
# 4     Worth every penny                                  excellent look...
# 5             Fabulous!  Everything is perfect pictures come out so cle...
# 6             Brilliant  A wort full value for money decision it’s . Si...
# 7        Simply awesome                                      Awsn loved it
# 8             Must buy!                                          Excellent
# 9   Best in the market!  first iphone from android.\nwhat can I say, ip...
# 10  Best in the market!  Don’t expect much from front camera… especiall...
#
#    Ratings
# 1        5
# 2        4
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5

# %%
next_btn=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]')
next_btn.click()

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')

review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)

ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)

# %%
df5=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df5.index +=1
df5
# Out:
#         Review_Summary                                        Full_Review  \
# 1            Just wow!  Loving it!!! 🤩\nSE to 11❤️\nA Big & Worthy Upg...
# 2     Perfect product!  Value for money\n5 star rating\nExcellent came...
# 3   Highly recommended  What a camera .....just awesome ..you can feel...
# 4       Simply awesome             over all its nice.. color... purple. 😍
# 5        Great product  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 6          Good choice  So far it’s been an AMAZING experience coming ...
# 7     Perfect product!                         Very nice iPhone 11 i lake
# 8            Just wow!  Switched from 6s and absolutely loving it 😍\nE...
# 9            Wonderful  I upgraded from 7 plus and Im not regretting i...
# 10   Worth every penny  iPhone is delivered on time. Display is great ...
#
#    Ratings
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        4
# 7        5
# 8        5
# 9        5
# 10       5

# %%
next_btn=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]')
next_btn.click()

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')

review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)

ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)
    
df6=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df6.index +=1
df6
# Out:
#           Review_Summary                                        Full_Review  \
# 1              Wonderful  Its good.. a little heavy on my pinky but its ...
# 2              Fabulous!  This is my first iOS phone. I am very happy wi...
# 3              Wonderful                          Definitely worth purchase
# 4              Brilliant                                    Fantastic phone
# 5              Fabulous!  Gift this to your loved ones fabulous product ...
# 6              Just wow!                                       Product 100%
# 7     Highly recommended  Amazing camera quality as expected, battery al...
# 8                Awesome  iPhone 11 is a good phone. Not a very big diff...
# 9   Good quality product  I'm switching this phone to oppo reno 10x zoom...
# 10           Pretty good  I was using Iphone 6s and also Oneplus 6t. Bot...
#
#    Ratings
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# 9        4
# ...

# %%
next_btn=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]')
next_btn.click()

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')

review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)

ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)
    
df7=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df7.index +=1
df7
# Out:
#            Review_Summary                                        Full_Review  \
# 1               Excellent  A perfect phone and a good battery super camer...
# 2       Terrific purchase                                          Awesome 💙
# 3               Excellent  Review After 10month\nSuperb quality product\n...
# 4   Mind-blowing purchase                                      I’m satisfy😍😍
# 5               Must buy!  This is my first Iphone. Very smooth and super...
# 6      Highly recommended  My first ever I phone and awesome performance ...
# 7        Perfect product!  Value for money❤️❤️\nIts awesome mobile phone ...
# 8          Classy product  The camera of this mobile is very good, batter...
# 9   Mind-blowing purchase  Absolutely powerful gadget. Loved it’s look! S...
# 10      Worth every penny  i11 is worthy to buy, too much happy with the ...
#
#    Ratings
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# ...

# %%
next_btn=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]')
next_btn.click()

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')

review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)

ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)
    
df8=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df8.index +=1
df8
# Out:
#            Review_Summary                                        Full_Review  \
# 1               Wonderful                                 Value for money ✌️
# 2      Highly recommended  iphone 11 is a very good phone to buy only if ...
# 3               Wonderful  Excellent Fabulous Adorable Iphone 11 Value fo...
# 4               Must buy!                           .excellent .100/100🥰🥰🥰🥰💥
# 5               Wonderful                                     Quality camera
# 6               Must buy!  Best Apple iPhone that i have bought at a very...
# 7                  Super!  Exactly mach what you expect and where Spent y...
# 8      Highly recommended  Excellent product but packing was not upto mark..
# 9               Must buy!                                           happy ❤️
# 10  Mind-blowing purchase  Excellent camera 📸 And Display touching very N...
#
#    Ratings
# 1        4
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# ...

# %%
next_btn=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]')
next_btn.click()

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')

review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)

ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)
    
df9=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df9.index +=1
df9
# Out:
#          Review_Summary                                        Full_Review  \
# 1        Classy product                        Just enjoy the power of it!
# 2       Value-for-money  Just got this iphone 11\nAnd it is most powerf...
# 3      Perfect product!  Iphone is just awesome.. battery backup is ver...
# 4         Great product  Awesome phone, great display(may not be a OLED...
# 5         Great product                                     Superb Phone..
# 6             Just wow!                                         Loved it!!
# 7         Great product  I was using android phone earlier..I was think...
# 8      Perfect product!  It is just awesome mobile for this price from ...
# 9   Best in the market!  Really very nice... my dad gifted me really I ...
# 10            Wonderful  Simply awesome device\nPerfect camera\nAwesome...
#
#    Ratings
# 1        5
# 2        4
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5

# %%
next_btn=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]')
next_btn.click()

# %%
review_tag=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')

review=[]
for i in review_tag:
    review.append(i.text)

full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')

full_review1=[]
for i in full_review:
    full_review1.append(i.text)

ratings_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')

Ratings=[]
for i in ratings_tag:
    Ratings.append(i.text)
    
df10=pd.DataFrame({'Review_Summary':review,'Full_Review':full_review1,'Ratings':Ratings})
df10.index +=1
df10
# Out:
#          Review_Summary                                        Full_Review  \
# 1        Classy product  We are on apple ecosystem for almost eight yea...
# 2   Best in the market!  Just awesome everything is perfect.\nCamera ou...
# 3    Highly recommended                        Loving it!!!Great product👌🏻
# 4             Just wow!                                    Excellent Phone
# 5                Super!  Did an upgrade from 6s plus to iphone 11.\nAo ...
# 6             Just wow!  Best in class. Battery backup is good especial...
# 7             Excellent  Using this phone from last 4days, great camera...
# 8          Does the job                                 Very good ☺️ phone
# 9     Worth every penny  It is better to buy iPhone 11 over iPhone 12 i...
# 10            Must buy!  My dream is complete just mind-blowing phone c...
#
#    Ratings
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        3
# 9        5
# 10       5

# %%
Data = pd.concat([df1, df2,df3, df4,df5,df6,df7,df8,df9,df10], axis=0)
Data
# Out:
#        Review_Summary                                        Full_Review  \
# 1            Terrific                                     Very very good
# 2      Classy product  Camera is awesome\nBest battery backup\nA perf...
# 3           Wonderful                             This is amazing at all
# 4           Brilliant                                   Excellent Phone.
# 5           Must buy!                                It’s really awesome
# ..                ...                                                ...
# 6           Just wow!  Best in class. Battery backup is good especial...
# 7           Excellent  Using this phone from last 4days, great camera...
# 8        Does the job                                 Very good ☺️ phone
# 9   Worth every penny  It is better to buy iPhone 11 over iPhone 12 i...
# 10          Must buy!  My dream is complete just mind-blowing phone c...
#
#    Ratings
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# ..     ...
# ...

# %% [markdown]
# # Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
url=" https://www.flipkart.com/"
driver.get(url)

# %%
search_bar=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search_bar.send_keys("sneakers")

# %%
search_btn=driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
search_btn.click()

# %%
brand=[]
prod1=[]
prod2=[]
price=[]
discount=[]


for page in range(0,5):
    
 
    for i in driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]'):
        brand.append(i.text)
        

    for j in driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]'):
        prod1.append(j.text)
        
    for c in driver.find_elements(By.XPATH,'//a[@class="IRpwTa _2-ICcC"]'):
        prod2.append(c.text)
    prod=prod1+prod2
    

    for k in driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]'):
        price.append(k.text)
        
 
    for l in driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]'):
        discount.append(l.text)
        

    nxt_button=driver.find_elements(By.XPATH,'//a[@class="ge-49M _2Kfbh8"]')
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))
        

Sneaker_data=pd.DataFrame({'Brand':brand,'Product Description':prod,'Price':price,'Discount':discount})
Sneaker_data.head(100)
# Out:
#        Brand                                Product Description Price Discount
# 0     BRUTON    !Combo Pack Of 2 Casual Shoes! Sneakers For Men  ₹479  80% off
# 1   HOTSTYLE                      2 Pair Combo Sneakers For Men  ₹499  75% off
# 2       aadi  Synthetic Leather |Lightweight|Comfort|Summer|...  ₹399  80% off
# 3       aadi  Synthetic Leather |Lightweight|Comfort|Summer|...  ₹499  75% off
# 4        SFR                                   Sneakers For Men  ₹348  65% off
# ..       ...                                                ...   ...      ...
# 95      aadi                                   Sneakers For Men  ₹299  70% off
# 96    BRUTON  asian Thunder-01 White Color Change Sneakers,C...  ₹479  80% off
# 97    BRUTON                                   Sneakers For Men  ₹479  80% off
# 98  PrasKing  Lightweight,Comfort,Summer,Trendy,Walking,Outd...  ₹584  41% off
# 99      aadi  Combo Pack Of 4 Casual Shoes Loafer Shoes Snea...  ₹399  60% off
#
# [100 rows x 4 columns]

# %% [markdown]
# # Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then
# set CPU Type filter to “Intel Core i7” as shown in the below image:
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
url="https://www.amazon.in/"
driver.get(url)

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search.send_keys('Laptop')

# %%
search_button=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_button.click()

# %%
CPU_check=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[7]/span[13]/li/span/a/span')
CPU_check.click()

# %%
laptop_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')

laptop=[]

for i in laptop_tags:
    laptop.append(i.text)
len(laptop)
laptop=laptop[:10]
laptop
# Out:
# ['Acer Aspire 7 AMD Ryzen 5 Hexa Core 5500U 15.6 inches Gaming',
#  '(8GB/512GB SSD/Windows 11 Home/4GB Graphics/NVIDIA GeForce GTX 1650) A715-42G, Black, 2.15Kg',
#  'Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light',
#  '(16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN',
#  'Dell Inspiron 5430 13th Gen',
#  ', Intel i7-1360P/16GB/1TB SSD/14.0" (35.56CMs) FHD+ WVA AG with Comfortview Support 250 nits/Backlit KB+FPR/Win 11+MSO\'21/15 Month McAfee/Platinum Silver/1.59KGs',
#  'ASUS Vivobook 15, Intel Core i7-12650H 12th Gen, 15.6" (39.62 cm) FHD, Thin and Light',
#  '',
#  'Lenovo [SmartChoice] IdeaPad Slim 3 Intel Core i7 11th Gen 15.6" (39.62cm) FHD',
#  '(16GB/512GB SSD/Win 11/Office 2021/2 Years Warranty/Arctic Grey/1.65Kg), 82H803B6IN']

# %%
rating_tags=driver.find_elements(By.XPATH,'//i[@class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"]')[:10]
Ratings=[]
for j in rating_tags:
    
    try:
        Ratings.append(j.get_attribute("innerText"))
    except:
        Ratings.append("No_Ratings")
Ratings
# Out:
# ['4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.1 out of 5 stars',
#  '3.9 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.1 out of 5 stars']

# %%
price_tag=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
len(price_tag)
Price=[]
for i in price_tag:
    Price.append(i.text)
len(Price)
Price=Price[:10]
Price
# Out:
# ['56,990',
#  '80,990',
#  '86,420',
#  '61,990',
#  '62,990',
#  '1,04,990',
#  '97,999',
#  '70,990',
#  '79,990',
#  '1,15,990']

# %%
data=pd.DataFrame()
data['Laptop']=laptop
data['Price']=Price
data['Ratings']=Ratings
data.index+=1
data
# Out:
#                                                Laptop     Price  \
# 1   Acer Aspire 7 AMD Ryzen 5 Hexa Core 5500U 15.6...    56,990
# 2   (8GB/512GB SSD/Windows 11 Home/4GB Graphics/NV...    80,990
# 3   Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...    86,420
# 4   (16GB/512GB SSD/Windows 11/Office 2021/Backlit...    61,990
# 5                         Dell Inspiron 5430 13th Gen    62,990
# 6   , Intel i7-1360P/16GB/1TB SSD/14.0" (35.56CMs)...  1,04,990
# 7   ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...    97,999
# 8                                                        70,990
# 9   Lenovo [SmartChoice] IdeaPad Slim 3 Intel Core...    79,990
# 10  (16GB/512GB SSD/Win 11/Office 2021/2 Years War...  1,15,990
#
#                Ratings
# 1   4.1 out of 5 stars
# 2   4.1 out of 5 stars
# 3   4.0 out of 5 stars
# 4   4.1 out of 5 stars
# 5   3.9 out of 5 stars
# 6   4.0 out of 5 stars
# 7   4.0 out of 5 stars
# 8   4.0 out of 5 stars
# 9   4.0 out of 5 stars
# ...

# %% [markdown]
# # Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpage https://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
url="https://www.azquotes.com/"
driver.get(url)

search_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
search_button.click()

quote_tag=driver.find_elements(By.XPATH,'//a[@class="title"]')
Quote=[]
for i in quote_tag:
    Quote.append(i.text)

len(Quote)

author=driver.find_elements(By.XPATH,'//div[@class="author"]')

Author=[]
for i in author:
    Author.append(i.text)
len(Author)


type_of_quote=driver.find_elements(By.XPATH,'//div[@class="tags"]')

Type_of_Quote=[]
for i in type_of_quote:
    Type_of_Quote.append(i.text)
len(Type_of_Quote)

data=pd.DataFrame({'Quote':quote_tag,'Author':author,'Type_of_quote':type_of_quote,})


quote_tag = [element.text for element in data.iloc[:, 0]]

author = [element.text for element in data.iloc[:, 1]]

type_of_quote = [element.text for element in data.iloc[:, 2]]


data_with_text = pd.DataFrame({'Quote': quote_tag, 'Author': author, 'Type_of_quote': type_of_quote})
data_with_text.head(100)
# Out:
#                                                 Quote                Author  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                                Type_of_quote
# ...

# %% [markdown]
# # Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,
# Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame

# %%
url="https://www.jagranjosh.com/"
driver.get(url)

# %%
CPU_check=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[3]/a')
CPU_check.click()

# %%
CPU_check=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
CPU_check.click()

# %%
PM_NAME=[]
for i in driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')[:18]:
    PM_NAME.append(i.text)
    
len(PM_NAME)
# Out:
# 18

# %%
BORN_DEAD=[]
for i in driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')[:18]:
    BORN_DEAD.append(i.text)
    
len(BORN_DEAD)
# Out:
# 18

# %%
Term_of_Office=[]
for i in driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]/p'):
    Term_of_Office.append(i.text.split(',')[0].strip())
    
Term_of_Office_without_duration = []
for i in range(len(Term_of_Office)):
    if i % 2 == 0:  
        Term_of_Office_without_duration.append(Term_of_Office[i])

Term_of_Office_without_duration
# Out:
# ['15 August 1947 to 27 May 1964',
#  '27 May 1964 to 9 June 1964',
#  '9 June 1964 to 11 January 1966',
#  '11 January 1966 to 24 January 1966',
#  '24 January 1966 to 24 March 1977',
#  '24 March 1977 to  28 July 1979',
#  '28 July 1979 to 14 January 1980',
#  '14 January 1980 to 31 October 1984',
#  '31 October 1984 to 2 December 1989',
#  '2 December 1989 to 10 November 1990',
#  '10 November 1990 to 21 June 1991',
#  '21 June 1991 to 16 May 1996',
#  '16 May 1996 to 1 June 1996',
#  '1 June 1996 to 21 April 1997',
#  '21 April 1997 to 19 March 1998',
#  '19 March 1998 to 22 May 2004',
#  '22 May 2004 to 26 May 2014',
#  '26 May 2014 - 2019']

# %%
Remarks=[]
for i in driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')[:18]:
    Remarks.append(i.text)
    
len(Remarks)
# Out:
# 18

# %%
data=pd.DataFrame({'PM_NAME':PM_NAME,'BORN_DEAD':BORN_DEAD,'Term_of_Office_without_duration':Term_of_Office_without_duration,'Remarks':Remarks})
data
# Out:
#                         PM_NAME     BORN_DEAD  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#         Term_of_Office_without_duration  \
# ...

# %% [markdown]
# # Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e.
# Car name and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to type in the search bar ’50 most expensive cars’
# 3. Then click on 50 most expensive cars in the world..
# 4. Then scrap the mentioned data and make the dataframe.

# %%
url="https://www.motor1.com/"
driver.get(url)

# %%
search_bar=driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/input')
search_bar.send_keys('50 most expensive cars')

# %%
search = driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/button[1]')
search.click()

# %%
search_nxt = driver.find_element(By.XPATH,'/html/body/div[10]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a')
search_nxt.click()

# %%
car_name=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')[:50]
CAR_NAME=[]
for i in car_name:
    CAR_NAME.append(i.text)
len(CAR_NAME)
# Out:
# 50

# %%
prices = []

prices_50expcars = driver.find_elements(By.XPATH,"//strong")

for j in prices_50expcars:

        prices.append(j.text)

prices.pop(4)
# Out:
# 'Price: $1.7 Million'

# %%
data= pd.DataFrame({"CAR_NAME":CAR_NAME,"PRICE":prices})
data.index +=1
data
# Out:
#                            CAR_NAME                        PRICE
# 1                     De Tomaso P72          Price: $1.3 Million
# 2                 Ferrari LaFerrari          Price: $1.4 Million
# 3                     Pagani Huayra          Price: $1.4 Million
# 4                      McLaren Elva
# 5                       Czinger 21C          Price: $1.7 Million
# 6                     Ferrari Monza          Price: $1.7 Million
# 7                Gordon Murray T.33          Price: $1.7 Million
# 8                 Koenigsegg Gemera          Price: $1.7 Million
# 9                       Zenvo TSR-S          Price: $1.7 Million
# 10               Hennessey Venom F5          Price: $1.8 Million
# 11                  Bentley Bacalar          Price: $1.9 Million
# 12    Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 13           Bentley Mulliner Batur          Price: $2.0 Million
# 14                     Deus Vayanne          Price: $2.0 Million
# ...
